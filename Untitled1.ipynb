# %% [markdown]
# <a href="https://colab.research.google.com/github/Shekinahh/boot-camp-gdsc/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data_path = "/hour.csv"
data = pd.read_csv(data_path)
data.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
data.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
y = data.registered
data_features = ['weathersit','weekday','hr']
X=data[data_features]
X.describe()
# Out:
#          weathersit       weekday            hr
# count  17379.000000  17379.000000  17379.000000
# mean       1.425283      3.003683     11.546752
# std        0.639357      2.005771      6.914405
# min        1.000000      0.000000      0.000000
# 25%        1.000000      1.000000      6.000000
# 50%        1.000000      3.000000     12.000000
# 75%        2.000000      5.000000     18.000000
# max        4.000000      6.000000     23.000000

# %%
X.head()
# Out:
#    weathersit  weekday  hr
# 0           1        6   0
# 1           1        6   1
# 2           1        6   2
# 3           1        6   3
# 4           1        6   4

# %%
from sklearn.tree import DecisionTreeRegressor

data_model = DecisionTreeRegressor(random_state=1)

data_model.fit(X,y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
print("making prediction")
print(X.head())
print("prediction are")
print(data_model.predict(X.head()))
# Out:
# making prediction
#    weathersit  weekday  hr
# 0           1        6   0
# 1           1        6   1
# 2           1        6   2
# 3           1        6   3
# 4           1        6   4
# prediction are
# [87.55263158 60.26865672 43.24242424 18.44444444  5.84507042]
